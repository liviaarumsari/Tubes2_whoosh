# %% [markdown]
# ### Imports

# %%
import pandas as pd 
import numpy as np
import math
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB, CategoricalNB

# %% [markdown]
# ### Import data

# %%
df_train = pd.read_csv('data/data_train.csv')
df_train.head()

df_test = pd.read_csv('data/data_validation.csv')
df_test.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1            563     1          0.5         1   2       1          41    0.9
# 2            769     1          2.9         1   0       0           9    0.1
# 3            775     0          1.0         0   3       0          46    0.7
# 4            595     0          0.9         1   7       1          23    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        145        5  ...       1263      1716  2603    11     2          9
# 2        182        5  ...        248       874  3946     5     2          7
# 3        159        2  ...        862      1864   568    17    15         11
# 4        121        3  ...        441       810  3752    10     2         18
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        0             0     0            3
# 3        1             1     1            0
# 4        1             1     0            3
#
# [5 rows x 21 columns]

# %%
x_train = df_train.drop('price_range',axis=1)
y_train = df_train['price_range']

x_test = df_test.drop('price_range',axis=1)
y_test = df_test['price_range']

x_train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               804     1          0.8         1  12       1          41
# 1              1042     0          2.2         0  15       1          11
# 2              1481     1          2.0         1   0       0          35
# 3              1104     0          1.7         0   1       1          60
# 4               652     0          0.5         1   1       0          58
# ...             ...   ...          ...       ...  ..     ...         ...
# 1395            536     1          1.4         0   0       1          53
# 1396           1097     0          0.8         0  10       1          21
# 1397           1179     1          0.5         0   7       1          32
# 1398            719     1          0.5         1   0       1          23
# 1399           1439     0          0.9         0  12       1          20
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.9         89        1  13        709       818  2027    11     5
# 1       0.6        139        5  16         68      1018  2826    18     0
# 2       0.5        105        3   0        249       522  2635    17    16
# 3       0.4        199        2  13        653      1413  1229     6     0
# 4       0.6        142        3   2        464       781   565    18    12
# ...     ...        ...      ...  ..        ...       ...   ...   ...   ...
# 1395    0.7        135        3   0        547       705  1211    15    10
# 1396    0.1        160        7  15       1277      1352  2219    15     6
# 1397    0.3        182        2  12         85      1451   340    16     5
# 1398    0.4        113        6   9        431      1727  3990    14     9
# 1399    0.8        147        1  17        626       932  1790    19    12
#
#       talk_time  three_g  touch_screen  wifi
# 0            11        1             0     0
# 1             2        1             0     0
# 2             4        1             0     1
# 3             3        1             1     1
# 4             9        0             0     1
# ...         ...      ...           ...   ...
# 1395          7        1             0     1
# 1396         12        1             0     1
# 1397         16        1             0     0
# 1398         12        1             1     1
# 1399         15        1             0     1
#
# [1400 rows x 20 columns]

# %% [markdown]
# ### Find numeric and categorical columns

# %%
num_columns = ["battery_power", "clock_speed", "fc", "int_memory", "m_dep", "mobile_wt", "n_cores", "pc", "px_height", "px_width", "ram", "sc_h", "sc_w", "talk_time", "price_range"]
non_num_columns = ["blue", "dual_sim", "four_g", "three_g", "touch_screen", "wifi"]

numeric_columns = num_columns
categorical_columns = non_num_columns

# %%
# Numeric columns
model_gnb = GaussianNB()
model_gnb.fit(df_train[numeric_columns], y_train)

# Categorical columns
model_cnb = CategoricalNB()
model_cnb.fit(df_train[categorical_columns], y_train)

categorical_posteriors = model_cnb.predict_proba(df_test[categorical_columns])
numerical_posteriors   = model_gnb.predict_proba(df_test[numeric_columns])
print(numerical_posteriors)

combined_probabilities = categorical_posteriors * numerical_posteriors

# Get the class with the highest combined probability as the final prediction
final_predictions = np.argmax(combined_probabilities, axis=1)
final_predictions
# Out:
# [[9.34761549e-192 1.00000000e+000 9.78616349e-187 0.00000000e+000]
#  [0.00000000e+000 1.99746688e-188 1.00000000e+000 1.57515699e-188]
#  [0.00000000e+000 0.00000000e+000 5.36898744e-188 1.00000000e+000]
#  ...
#  [1.00000000e+000 8.04264346e-188 0.00000000e+000 0.00000000e+000]
#  [0.00000000e+000 2.50867017e-187 1.00000000e+000 1.53807895e-189]
#  [0.00000000e+000 0.00000000e+000 2.97070861e-188 1.00000000e+000]]
# array([1, 2, 3, 0, 3, 1, 3, 0, 3, 2, 3, 2, 3, 0, 3, 0, 2, 1, 1, 2, 3, 2,
#        0, 1, 2, 0, 3, 1, 0, 3, 1, 3, 3, 0, 2, 3, 1, 3, 2, 1, 1, 2, 0, 2,
#        3, 1, 1, 2, 2, 3, 2, 2, 3, 0, 1, 3, 1, 3, 3, 2, 2, 3, 3, 1, 3, 2,
#        3, 2, 3, 3, 2, 3, 1, 0, 1, 2, 0, 3, 1, 0, 3, 3, 1, 2, 3, 2, 3, 3,
#        0, 2, 1, 1, 1, 2, 2, 1, 3, 2, 0, 3, 3, 3, 1, 2, 3, 1, 3, 3, 3, 3,
#        3, 3, 2, 2, 3, 1, 0, 2, 1, 3, 1, 2, 2, 3, 3, 0, 2, 2, 1, 3, 3, 1,
#        0, 0, 3, 1, 0, 2, 3, 0, 1, 3, 3, 1, 2, 3, 1, 2, 1, 1, 3, 0, 0, 2,
#        1, 1, 2, 0, 1, 3, 3, 3, 0, 2, 3, 0, 0, 2, 1, 2, 2, 1, 0, 1, 0, 1,
#        3, 1, 2, 0, 3, 1, 1, 2, 0, 2, 0, 3, 2, 0, 3, 2, 0, 0, 2, 0, 1, 3,
#        3, 1, 1, 2, 2, 3, 2, 3, 3, 3, 0, 2, 1, 2, 3, 1, 1, 2, 3, 0, 0, 2,
#        2, 1, 2, 3, 1, 2, 0, 3, 0, 2, 2, 2, 2, 2, 3, 0, 2, 3, 3, 3, 0, 0,
#        1, 0, 3, 3, 1, 1, 0, 2, 2, 1, 3, 3, 0, 2, 2, 0, 0, 1, 0, 2, 2, 3,
#        3, 0, 2, 3, 3, 0, 0, 2, 1, 2, 1, 0, 3, 2, 2, 2, 0, 1, 0, 2, 1, 1,
#        0, 1, 3, 1, 3, 0, 1, 0, 1, 3, 2, 3, 0, 3, 1, 0, 0, 1, 2, 2, 0, 3,
#        1, 1, 0, 2, 3, 1, 3, 2, 3, 1, 2, 3, 0, 0, 3, 1, 2, 1, 0, 0, 1, 0,
#        3, 2, 3, 2, 2, 3, 3, 0, 1, 0, 1, 1, 0, 2, 2, 2, 2, 2, 1, 1, 3, 0,
#        2, 2, 2, 2, 1, 3, 3, 0, 3, 0, 0, 3, 2, 0, 3, 2, 1, 2, 0, 0, 2, 2,
#        2, 3, 0, 0, 2, 2, 0, 2, 1, 1, 3, 2, 3, 3, 1, 1, 0, 3, 1, 0, 3, 1,
#        0, 2, 0, 3, 1, 0, 1, 0, 1, 2, 1, 1, 1, 2, 3, 1, 2, 2, 3, 1, 1, 2,
#        2, 2, 0, 1, 3, 0, 0, 2, 0, 0, 0, 3, 0, 1, 1, 0, 0, 2, 1, 0, 3, 2,
#        1, 0, 1, 1, 2, 1, 1, 1, 2, 0, 1, 2, 0, 1, 0, 3, 0, 0, 1, 2, 2, 1,
#        3, 1, 1, 3, 3, 0, 2, 2, 0, 1, 2, 1, 0, 1, 2, 0, 2, 0, 2, 3, 0, 0,
#        3, 0, 1, 3, 3, 3, 2, 2, 3, 0, 1, 2, 1, 2, 1, 0, 3, 1, 3, 3, 2, 1,
#        3, 0, 3, 3, 1, 3, 0, 3, 0, 2, 2, 0, 2, 3, 1, 3, 0, 2, 3, 3, 0, 2,
#        1, 2, 3, 2, 3, 1, 2, 0, 3, 3, 3, 1, 1, 3, 1, 0, 0, 0, 3, 0, 2, 2,
#        1, 3, 2, 1, 2, 3, 0, 3, 0, 0, 3, 3, 2, 0, 1, 2, 0, 2, 0, 1, 0, 2,
#        0, 1, 0, 0, 1, 3, 0, 1, 1, 1, 0, 0, 2, 0, 1, 3, 0, 2, 1, 1, 0, 2,
#        3, 1, 3, 0, 2, 3], dtype=int64)

# %%
from lib.naive_bayes import NaiveBayesNumerical

manual_nb = NaiveBayesNumerical()
manual_nb.fit(df_train[numeric_columns].values.T, y_train.values)
category_manual = manual_nb.predictProbaNumerical(df_test[numeric_columns].values)
category_manual
# Out:
# NOL
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# d:\ITB Files\AI\Tubes2-whoosh\nb copy.ipynb Cell 10 line 3
#       <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> manual_nb = NaiveBayesClassifier(1)
#       <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> manual_nb.fit(df_train[numeric_columns].values.T, df_train[categorical_columns].values.T, y_train.values)
# ----> <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> category_manual = manual_nb.predictProbaNumerical(df_test[numeric_columns].values)
#       <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> category_manual
#
# d:\ITB Files\AI\Tubes2-whoosh\nb copy.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=22'>23</a> res = []
#      <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=23'>24</a> for x_test_row in x_test_numerical:
# ---> <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=24'>25</a>     numerical_probabilities = self.GaussianProbability(x_test_row)
#      <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=25'>26</a>     res.append(numerical_probabilities)
#      <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=26'>27</a> return res
#
# d:\ITB Files\AI\Tubes2-whoosh\nb copy.ipynb Cell 10 line 4
#      <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=45'>46</a> xi = x_numerical_test[col]
#      <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=47'>48</a> # log_target_given_x_probability = (-0.5 * np.log(2 * np.pi * var)) - (0.5 * (((xi - avg) ** 2) / var))
# ---> <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=48'>49</a> x_given_target_probability = (1 / math.sqrt(2 * np.pi * var)) * math.exp(- ((xi - avg) ** 2) / (2 * var))
#      <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=49'>50</a> # log_target_probabilities.append(log_target_given_x_probability)
#      <a href='vscode-notebook-cell:/d%3A/ITB%20Files/AI/Tubes2-whoosh/nb%20copy.ipynb#X13sZmlsZQ%3D%3D?line=50'>51</a> target_given_all_probabilities *= x_given_target_probability
#
# ZeroDivisionError: float division by zero

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score

def evaluate_classifier_performance(prediction, y_test):
    print('Accuracy Average:', accuracy_score(y_test, prediction))
    print('F1 Macro Average:', f1_score(y_test, prediction, average='macro'))
    print('F1 Micro Average:', f1_score(y_test, prediction, average='micro'))
    print('Precision Macro Average:', precision_score(y_test, prediction, average='macro',zero_division=0))
    print('Precision Micro Average:', precision_score(y_test, prediction, average='micro',zero_division=0))
    print('Recall Macro Average:', recall_score(y_test, prediction, average='macro',zero_division=0))
    print('Recall Micro Average:', recall_score(y_test, prediction, average='micro',zero_division=0))

# %%
evaluate_classifier_performance(final_predictions,y_test)
# Out:
# Accuracy Average: 1.0
# F1 Macro Average: 1.0
# F1 Micro Average: 1.0
# Precision Macro Average: 1.0
# Precision Micro Average: 1.0
# Recall Macro Average: 1.0
# Recall Micro Average: 1.0
